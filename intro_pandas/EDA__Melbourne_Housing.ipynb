# %% [markdown]
# <a href="https://colab.research.google.com/github/tamojit-maiti/upgrad-teaching/blob/main/intro_pandas/EDA_%7C_Melbourne_Housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Processing
#
# ### Importing the Data

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# %%
# Import data
dataset = pd.read_csv('https://raw.githubusercontent.com/StephanieStallworth/Exploratory_Data_Analysis_Visualization_Python/master/Melbourne_housing_extra_data.csv')

# %%
# Get number of rows and columns
dataset.shape
# Out:
# (17407, 21)

# %%
# View data
dataset.head()
# Out:
#        Suburb             Address  ...             Regionname Propertycount
# 0  Abbotsford       68 Studley St  ...  Northern Metropolitan          4019
# 1  Abbotsford        85 Turner St  ...  Northern Metropolitan          4019
# 2  Abbotsford     25 Bloomburg St  ...  Northern Metropolitan          4019
# 3  Abbotsford  18/659 Victoria St  ...  Northern Metropolitan          4019
# 4  Abbotsford        5 Charles St  ...  Northern Metropolitan          4019
#
# [5 rows x 21 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17407 entries, 0 to 17406
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         17407 non-null  object
#  1   Address        17407 non-null  object
#  2   Rooms          17407 non-null  int64
#  3   Type           17407 non-null  object
#  4   Price          13525 non-null  float64
#  5   Method         17407 non-null  object
#  6   SellerG        17407 non-null  object
#  7   Date           17407 non-null  object
#  8   Distance       17407 non-null  float64
#  9   Postcode       17407 non-null  int64
#  10  Bedroom2       13625 non-null  float64
#  11  Bathroom       13625 non-null  float64
#  12  Car            13625 non-null  float64
#  13  Landsize       13603 non-null  float64
#  14  BuildingArea   7323 non-null   float64
#  15  YearBuilt      8429 non-null   float64
#  16  CouncilArea    13601 non-null  object
#  17  Lattitude      13737 non-null  float64
#  18  Longtitude     13737 non-null  float64
#  19  Regionname     17407 non-null  object
#  20  Propertycount  17407 non-null  int64
# dtypes: float64(10), int64(3), object(8)
# memory usage: 2.8+ MB

# %%
# View column names
dataset.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
# Change column names
dataset.columns = ['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
       'Date', 'Distance', 'PostCode', 'Bedroom2', 'Bathroom', 'Car',
       'LandSize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
       'Longtitude', 'RegionName', 'PropertyCount']
dataset.head()
# Out:
#        Suburb             Address  ...             RegionName PropertyCount
# 0  Abbotsford       68 Studley St  ...  Northern Metropolitan          4019
# 1  Abbotsford        85 Turner St  ...  Northern Metropolitan          4019
# 2  Abbotsford     25 Bloomburg St  ...  Northern Metropolitan          4019
# 3  Abbotsford  18/659 Victoria St  ...  Northern Metropolitan          4019
# 4  Abbotsford        5 Charles St  ...  Northern Metropolitan          4019
#
# [5 rows x 21 columns]

# %%
# Remove unnecessary columns and reorder so independent variable is last
dataset = dataset[['Suburb','Rooms', 'Type','Method','Distance', 'PostCode', 'Bedroom2', 'Bathroom', 'Car',
       'LandSize', 'BuildingArea', 'YearBuilt', 'RegionName', 'PropertyCount','Price']]

dataset.head()
# Out:
#        Suburb  Rooms Type  ...             RegionName  PropertyCount      Price
# 0  Abbotsford      2    h  ...  Northern Metropolitan           4019        NaN
# 1  Abbotsford      2    h  ...  Northern Metropolitan           4019  1480000.0
# 2  Abbotsford      2    h  ...  Northern Metropolitan           4019  1035000.0
# 3  Abbotsford      3    u  ...  Northern Metropolitan           4019        NaN
# 4  Abbotsford      3    h  ...  Northern Metropolitan           4019  1465000.0
#
# [5 rows x 15 columns]

# %% [markdown]
# ## Missing Values

# %%
# Visualize missing values
sns.heatmap(dataset.isnull(),yticklabels = False, cbar = False, cmap = 'viridis')
plt.show()

# %%
# Count of missing values for each column
dataset.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# Distance             0
# PostCode             0
# Bedroom2          3782
# Bathroom          3782
# Car               3782
# LandSize          3804
# BuildingArea     10084
# YearBuilt         8978
# RegionName           0
# PropertyCount        0
# Price             3882
# dtype: int64

# %%
# Percentage of values missing
dataset.isnull().sum()/len(dataset) *100
# Out:
# Suburb           0.0
# Rooms            0.0
# Type             0.0
# Method           0.0
# Distance         0.0
# PostCode         0.0
# Bedroom2         0.0
# Bathroom         0.0
# Car              0.0
# LandSize         0.0
# BuildingArea     0.0
# YearBuilt        0.0
# RegionName       0.0
# PropertyCount    0.0
# Price            0.0
# dtype: float64

# %%
# Remove missing rows
# to remove missing rows from a specific column: dataset = dataset[pd.notnull(dataset['Price'])]
dataset = dataset.dropna() # set axis to 1 to drop entire columns that have a missing value

# %% [markdown]
# ## Data Types

# %%
# View data types
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5386 entries, 2 to 17405
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         5386 non-null   object
#  1   Rooms          5386 non-null   int64
#  2   Type           5386 non-null   object
#  3   Method         5386 non-null   object
#  4   Distance       5386 non-null   float64
#  5   PostCode       5386 non-null   int64
#  6   Bedroom2       5386 non-null   float64
#  7   Bathroom       5386 non-null   float64
#  8   Car            5386 non-null   float64
#  9   LandSize       5386 non-null   float64
#  10  BuildingArea   5386 non-null   float64
#  11  YearBuilt      5386 non-null   float64
#  12  RegionName     5386 non-null   object
#  13  PropertyCount  5386 non-null   int64
#  14  Price          5386 non-null   float64
# dtypes: float64(8), int64(3), object(4)
# memory usage: 673.2+ KB

# %% [markdown]
# Non-null object types should be converted to categories to allow for better anaylysis.

# %%
# Identify object columns
dataset.select_dtypes(['object']).columns
# Out:
# Index(['Suburb', 'Type', 'Method', 'RegionName'], dtype='object')

# %%
# Convert non-null objects to category
o2c = dataset.select_dtypes(['object']).columns

for o in o2c:
    dataset[o] = dataset[o].astype('category')
    
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5386 entries, 2 to 17405
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         5386 non-null   category
#  1   Rooms          5386 non-null   int64
#  2   Type           5386 non-null   category
#  3   Method         5386 non-null   category
#  4   Distance       5386 non-null   float64
#  5   PostCode       5386 non-null   int64
#  6   Bedroom2       5386 non-null   float64
#  7   Bathroom       5386 non-null   float64
#  8   Car            5386 non-null   float64
#  9   LandSize       5386 non-null   float64
#  10  BuildingArea   5386 non-null   float64
#  11  YearBuilt      5386 non-null   float64
#  12  RegionName     5386 non-null   category
#  13  PropertyCount  5386 non-null   int64
#  14  Price          5386 non-null   float64
# dtypes: category(4), float64(8), int64(3)
# memory usage: 543.9 KB

# %% [markdown]
# Now it is time to examine the numeric variables by doing a statistical summary.

# %%
# Statistical summary
dataset.describe()
# Out:
#              Rooms    Distance  ...  PropertyCount         Price
# count  5386.000000  5386.00000  ...    5386.000000  5.386000e+03
# mean      2.913665     9.13173  ...    7409.758819  1.092251e+06
# std       0.971923     4.77895  ...    4332.894106  6.831677e+05
# min       1.000000     0.00000  ...     389.000000  1.310000e+05
# 25%       2.000000     5.90000  ...    4407.000000  6.352500e+05
# 50%       3.000000     8.70000  ...    6567.000000  9.000000e+05
# 75%       3.000000    11.80000  ...    9264.000000  1.350875e+06
# max       8.000000    47.40000  ...   21650.000000  8.000000e+06
#
# [8 rows x 11 columns]

# %% [markdown]
# From the stats summary above, it appears some numeric columns are  assigned to the wrong data type.
#
# Rooms, Bedroom2, and Bathroom, Car, and Propertycount should not be treated as floats as they are discrete values and should be identified as integers.
#
# YearBuilt and Postcode will need to be changed as well (to categorical).

# %%
# Convert float to integer
f2i = ['Rooms','Bedroom2','Bathroom','Car']
for f in f2i:
       dataset[f] = dataset[f].astype('int')
dataset.describe().transpose()
       
# Convert appropriate columns to categorical
f2c = ['PostCode']
for ff in f2c:
    dataset[ff] = dataset[ff].astype('category')

# Confirm changes
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5386 entries, 2 to 17405
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         5386 non-null   category
#  1   Rooms          5386 non-null   int64
#  2   Type           5386 non-null   category
#  3   Method         5386 non-null   category
#  4   Distance       5386 non-null   float64
#  5   PostCode       5386 non-null   category
#  6   Bedroom2       5386 non-null   int64
#  7   Bathroom       5386 non-null   int64
#  8   Car            5386 non-null   int64
#  9   LandSize       5386 non-null   float64
#  10  BuildingArea   5386 non-null   float64
#  11  YearBuilt      5386 non-null   float64
#  12  RegionName     5386 non-null   category
#  13  PropertyCount  5386 non-null   int64
#  14  Price          5386 non-null   float64
# dtypes: category(5), float64(5), int64(5)
# memory usage: 518.7 KB

# %% [markdown]
# # Exploratory Analysis

# %%
# Feature engineering

# Convert price to millions
dataset['Price'] = dataset['Price']/1000000

# Home Age
dataset['Age'] = 2021 - dataset['YearBuilt'] 

# Identify homes older than 50 years old as historic
dataset['Historic'] = dataset.Age.map(lambda x: 1 if x>50 else 0)

# Confirm changes
dataset.head()
# Out:
#         Suburb  Rooms Type Method  ...  PropertyCount  Price    Age  Historic
# 2   Abbotsford      2    h      S  ...           4019  1.035  121.0         1
# 4   Abbotsford      3    h     SP  ...           4019  1.465  121.0         1
# 6   Abbotsford      4    h     VB  ...           4019  1.600    7.0         0
# 11  Abbotsford      3    h      S  ...           4019  1.876  111.0         1
# 14  Abbotsford      2    h      S  ...           4019  1.636  131.0         1
#
# [5 rows x 17 columns]

# %% [markdown]
# ## Univariate Analysis

# %%
# Create histogram
dataset.Price.plot(kind = 'hist', bins = 25)
plt.xlabel('Price in Millions')
# Out:
# Text(0.5, 0, 'Price in Millions')

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Categorical Features
# Next, I want to compare the relationship between the categorical features and the Price.

# %%
# Identify categorical variables
categorical = dataset.select_dtypes(['category']).columns
print(categorical)
len(categorical)
# Out:
# Index(['Suburb', 'Type', 'Method', 'RegionName'], dtype='object')
# 4

# %%
dataset
# Out:
#                    Suburb  Rooms Type  ...   Price    Age  Historic
# 2              Abbotsford      2    h  ...  1.0350  121.0         1
# 4              Abbotsford      3    h  ...  1.4650  121.0         1
# 6              Abbotsford      4    h  ...  1.6000    7.0         0
# 11             Abbotsford      3    h  ...  1.8760  111.0         1
# 14             Abbotsford      2    h  ...  1.6360  131.0         1
# ...                   ...    ...  ...  ...     ...    ...       ...
# 17390      West Melbourne      2    u  ...  0.6600   28.0         0
# 17400        Williamstown      2    u  ...  0.8800   21.0         0
# 17401  Williamstown North      3    h  ...  0.8620   81.0         1
# 17403             Wollert      4    h  ...  0.5950    9.0         0
# 17405          Yarraville      2    u  ...  0.7095   51.0         1
#
# [5386 rows x 17 columns]

# %%
plt.boxplot([dataset[dataset.Historic == 0].Price, dataset[dataset.Historic == 1].Price])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
sns.boxplot(x = dataset.Historic, y = dataset.Price, data = dataset)
plt.show()

# %% [markdown]
# **Examine relationships between all categorical features and price**

# %%
sns.boxplot(x = dataset.RegionName, y = dataset.Price, data = dataset)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.boxplot(x = dataset.Method, y = dataset.Price, data = dataset)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Numeric Features
# Next I want to analyze the numeric features as they relate to the indpedent variable, Price.

# %%
# Stat summary
dataset.describe()
# Out:
#              Rooms    Distance  ...      HomeAge     Historic
# count  5386.000000  5386.00000  ...  5386.000000  5386.000000
# mean      2.913665     9.13173  ...    54.681211     0.503528
# std       0.971923     4.77895  ...    38.850927     0.500034
# min       1.000000     0.00000  ...    -1.000000     0.000000
# 25%       2.000000     5.90000  ...    18.000000     0.000000
# 50%       3.000000     8.70000  ...    51.000000     1.000000
# 75%       3.000000    11.80000  ...    82.000000     1.000000
# max       8.000000    47.40000  ...   821.000000     1.000000
#
# [8 rows x 12 columns]

# %%
# Identify continuous variables
print(dataset.select_dtypes(['float']).columns)
# Out:
# Index(['Distance', 'LandSize', 'BuildingArea', 'YearBuilt', 'Price',
#        'HomeAge'],
#       dtype='object')

# %%
plt.scatter(dataset.Price, dataset.BuildingArea)

# %%
# Plot
sns.pairplot(dataset,
             vars= ['Price','Distance', 'LandSize', 'BuildingArea','Historic'], palette = 'viridis')

# %% [markdown]
# **Insights:**
# Prices for historic homes have more variation than that of non-historic homes (less than 50 years old).
# Homes that are a farther distance from the Central Business District (CDB) tend to be priced lower.

# %%
# Plot
g =sns.PairGrid(dataset,
             vars= ['Price','Distance', 'LandSize', 'BuildingArea','HomeAge','Historic'], 
             hue = 'Historic',
             palette = 'viridis')
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter, edgecolor = 'w', s = 40)

# %% [markdown]
# ## Questions

# %% [markdown]
# Has the price of houses increased steadily throughout the years? Can this behaviour be explained by some attribute(s)?
#
# Which region has the most/least expensive houses? The biggest houese?
#
# What factors do you think contributes inversely to the house price?
